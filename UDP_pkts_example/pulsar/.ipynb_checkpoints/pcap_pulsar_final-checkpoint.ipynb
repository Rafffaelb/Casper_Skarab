# %%
import os
import glob

import numpy as np
import datetime

import matplotlib.pyplot as plt

import struct

import pandas as pd

# %%
def convert_timestamp_to_utc(seconds, microseconds):
    # Create a datetime object from the seconds since epoch in UTC
    timestamp = datetime.datetime.utcfromtimestamp(seconds)
    
    # Add the microseconds part to the timestamp
    timestamp_with_microseconds = timestamp + datetime.timedelta(microseconds=microseconds)
    
    # Return the formatted datetime in UTC with microseconds
    return timestamp_with_microseconds.strftime('%Y-%m-%d %H:%M:%S.%f')

# %%
def read_pcap(file_path):
    with open(file_path, 'rb') as f:
        # Read the global header (24 bytes)
        global_header = f.read(24)
        magic_number, version_major, version_minor, this_zone, sigfigs, snap_len, link_type = struct.unpack('<IHHIIII', global_header)

        print("PCAP Global Header Information:")
        print(f"Magic Number: {hex(magic_number)}")
        print(f"Version: {version_major}.{version_minor}")
        print(f"Timezone: {this_zone}")
        print(f"Snapshot Length: {snap_len}")
        print(f"Link Type: {link_type}")

        # Now, read each packet's header and payload
        packet_count = 0
        while True:
            packet_header = f.read(16)
            if len(packet_header) < 16:
                break  # End of file or incomplete packet
            
            # Unpack the packet header (16 bytes)
            ts_sec, ts_usec, captured_len, packet_len = struct.unpack('<IIII', packet_header)
            
            # Convert timestamp to UTC
            timestamp_utc = convert_timestamp_to_utc(ts_sec, ts_usec)
            
            # Print packet header details
            print(f"\nPacket {packet_count + 1}:")
            print(f"Timestamp (UTC): {timestamp_utc}")
            print(f"Captured Length: {captured_len} bytes")
            print(f"Original Packet Length: {packet_len} bytes")

            # Read the payload (captured data)
            payload = f.read(captured_len)
            print(f"Payload (first 16 bytes): {payload[:16]}")

            packet_count += 1

# %%
# Example usage
file_path = 'zteste_2canais_fc110_2.pcap'  # Replace with your PCAP file path
read_pcap(file_path)
# Out:
# PCAP Global Header Information:
# Magic Number: 0xa1b2c3d4
# Version: 2.4
# Timezone: 0
# Snapshot Length: 262144
# Link Type: 1
#
# Packet 1:
# Timestamp (UTC): 2025-02-15 19:38:39.668442
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 2:
# Timestamp (UTC): 2025-02-15 19:38:39.668474
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 3:
# Timestamp (UTC): 2025-02-15 19:38:39.668481
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 4:
# Timestamp (UTC): 2025-02-15 19:38:39.668489
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 5:
# Timestamp (UTC): 2025-02-15 19:38:39.668495
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 6:
# Timestamp (UTC): 2025-02-15 19:38:39.668501
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 7:
# Timestamp (UTC): 2025-02-15 19:38:39.668509
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 8:
# Timestamp (UTC): 2025-02-15 19:38:39.668515
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9:
# Timestamp (UTC): 2025-02-15 19:38:39.668522
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 10:
# Timestamp (UTC): 2025-02-15 19:38:39.668529
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 11:
# Timestamp (UTC): 2025-02-15 19:38:39.668537
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 12:
# Timestamp (UTC): 2025-02-15 19:38:39.668543
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 13:
# Timestamp (UTC): 2025-02-15 19:38:39.668550
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 14:
# Timestamp (UTC): 2025-02-15 19:38:39.668557
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 15:
# Timestamp (UTC): 2025-02-15 19:38:39.668564
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 16:
# Timestamp (UTC): 2025-02-15 19:38:39.668572
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 17:
# Timestamp (UTC): 2025-02-15 19:38:39.668579
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 18:
# Timestamp (UTC): 2025-02-15 19:38:39.668585
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 19:
# Timestamp (UTC): 2025-02-15 19:38:39.668593
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 20:
# Timestamp (UTC): 2025-02-15 19:38:39.668598
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 21:
# Timestamp (UTC): 2025-02-15 19:38:39.668605
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 22:
# Timestamp (UTC): 2025-02-15 19:38:39.668619
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 23:
# Timestamp (UTC): 2025-02-15 19:38:39.668627
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 24:
# Timestamp (UTC): 2025-02-15 19:38:39.668636
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 25:
# Timestamp (UTC): 2025-02-15 19:38:39.668644
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 26:
# Timestamp (UTC): 2025-02-15 19:38:39.668655
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 27:
# Timestamp (UTC): 2025-02-15 19:38:39.668663
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 28:
# Timestamp (UTC): 2025-02-15 19:38:39.668672
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 29:
# Timestamp (UTC): 2025-02-15 19:38:39.668681
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 30:
# Timestamp (UTC): 2025-02-15 19:38:39.668690
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 31:
# Timestamp (UTC): 2025-02-15 19:38:39.668700
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 32:
# Timestamp (UTC): 2025-02-15 19:38:39.668710
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 33:
# Timestamp (UTC): 2025-02-15 19:38:39.668718
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 34:
# Timestamp (UTC): 2025-02-15 19:38:39.668726
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 35:
# Timestamp (UTC): 2025-02-15 19:38:39.668734
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 36:
# Timestamp (UTC): 2025-02-15 19:38:39.668743
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 37:
# Timestamp (UTC): 2025-02-15 19:38:39.668751
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 38:
# Timestamp (UTC): 2025-02-15 19:38:39.668759
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 39:
# Timestamp (UTC): 2025-02-15 19:38:39.668767
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 40:
# Timestamp (UTC): 2025-02-15 19:38:39.668775
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 41:
# Timestamp (UTC): 2025-02-15 19:38:39.668784
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 42:
# Timestamp (UTC): 2025-02-15 19:38:39.668792
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 43:
# Timestamp (UTC): 2025-02-15 19:38:39.668802
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 44:
# Timestamp (UTC): 2025-02-15 19:38:39.668811
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 45:
# Timestamp (UTC): 2025-02-15 19:38:39.668819
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 46:
# Timestamp (UTC): 2025-02-15 19:38:39.668828
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 47:
# Timestamp (UTC): 2025-02-15 19:38:39.668838
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 48:
# Timestamp (UTC): 2025-02-15 19:38:39.668846
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 49:
# Timestamp (UTC): 2025-02-15 19:38:39.668854
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 50:
# Timestamp (UTC): 2025-02-15 19:38:39.668860
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 51:
# Timestamp (UTC): 2025-02-15 19:38:39.668867
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 52:
# Timestamp (UTC): 2025-02-15 19:38:39.668873
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 53:
# Timestamp (UTC): 2025-02-15 19:38:39.668886
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 54:
# Timestamp (UTC): 2025-02-15 19:38:39.668894
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 55:
# Timestamp (UTC): 2025-02-15 19:38:39.668901
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 56:
# Timestamp (UTC): 2025-02-15 19:38:39.668908
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 57:
# Timestamp (UTC): 2025-02-15 19:38:39.668915
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 58:
# Timestamp (UTC): 2025-02-15 19:38:39.668922
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 59:
# Timestamp (UTC): 2025-02-15 19:38:39.668928
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 60:
# Timestamp (UTC): 2025-02-15 19:38:39.668935
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 61:
# Timestamp (UTC): 2025-02-15 19:38:39.668942
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 62:
# Timestamp (UTC): 2025-02-15 19:38:39.668949
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 63:
# Timestamp (UTC): 2025-02-15 19:38:39.668956
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 64:
# Timestamp (UTC): 2025-02-15 19:38:39.668964
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 65:
# Timestamp (UTC): 2025-02-15 19:38:39.668976
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 66:
# Timestamp (UTC): 2025-02-15 19:38:39.668983
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 67:
# Timestamp (UTC): 2025-02-15 19:38:39.668990
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 68:
# Timestamp (UTC): 2025-02-15 19:38:39.668997
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 69:
# Timestamp (UTC): 2025-02-15 19:38:39.669004
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 70:
# Timestamp (UTC): 2025-02-15 19:38:39.669011
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 71:
# Timestamp (UTC): 2025-02-15 19:38:39.669017
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 72:
# Timestamp (UTC): 2025-02-15 19:38:39.669024
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 73:
# Timestamp (UTC): 2025-02-15 19:38:39.669031
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 74:
# Timestamp (UTC): 2025-02-15 19:38:39.669038
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 75:
# Timestamp (UTC): 2025-02-15 19:38:39.669049
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 76:
# Timestamp (UTC): 2025-02-15 19:38:39.669058
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 77:
# Timestamp (UTC): 2025-02-15 19:38:39.669067
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 78:
# Timestamp (UTC): 2025-02-15 19:38:39.669078
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 79:
# Timestamp (UTC): 2025-02-15 19:38:39.669087
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 80:
# Timestamp (UTC): 2025-02-15 19:38:39.669096
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 81:
# Timestamp (UTC): 2025-02-15 19:38:39.669106
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 82:
# Timestamp (UTC): 2025-02-15 19:38:39.669118
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 83:
# Timestamp (UTC): 2025-02-15 19:38:39.669131
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 84:
# Timestamp (UTC): 2025-02-15 19:38:39.669146
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 85:
# Timestamp (UTC): 2025-02-15 19:38:39.669151
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 86:
# Timestamp (UTC): 2025-02-15 19:38:39.669157
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 87:
# Timestamp (UTC): 2025-02-15 19:38:39.669162
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 88:
# Timestamp (UTC): 2025-02-15 19:38:39.669167
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 89:
# Timestamp (UTC): 2025-02-15 19:38:39.669172
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 90:
# Timestamp (UTC): 2025-02-15 19:38:39.669177
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 91:
# Timestamp (UTC): 2025-02-15 19:38:39.669182
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 92:
# Timestamp (UTC): 2025-02-15 19:38:39.669186
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 93:
# Timestamp (UTC): 2025-02-15 19:38:39.669190
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 94:
# Timestamp (UTC): 2025-02-15 19:38:39.669195
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 95:
# Timestamp (UTC): 2025-02-15 19:38:39.669199
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 96:
# Timestamp (UTC): 2025-02-15 19:38:39.669204
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 97:
# Timestamp (UTC): 2025-02-15 19:38:39.669209
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 98:
# Timestamp (UTC): 2025-02-15 19:38:39.669213
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 99:
# Timestamp (UTC): 2025-02-15 19:38:39.669217
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 100:
# Timestamp (UTC): 2025-02-15 19:38:39.669222
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 101:
# Timestamp (UTC): 2025-02-15 19:38:39.669226
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 102:
# Timestamp (UTC): 2025-02-15 19:38:39.669231
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 103:
# Timestamp (UTC): 2025-02-15 19:38:39.669234
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 104:
# Timestamp (UTC): 2025-02-15 19:38:39.669239
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 105:
# Timestamp (UTC): 2025-02-15 19:38:39.669244
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 106:
# Timestamp (UTC): 2025-02-15 19:38:39.669249
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 107:
# Timestamp (UTC): 2025-02-15 19:38:39.669255
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 108:
# Timestamp (UTC): 2025-02-15 19:38:39.669260
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 109:
# Timestamp (UTC): 2025-02-15 19:38:39.669264
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 110:
# Timestamp (UTC): 2025-02-15 19:38:39.669268
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 111:
# Timestamp (UTC): 2025-02-15 19:38:39.669272
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 112:
# Timestamp (UTC): 2025-02-15 19:38:39.669277
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 113:
# Timestamp (UTC): 2025-02-15 19:38:39.669281
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 114:
# Timestamp (UTC): 2025-02-15 19:38:39.669285
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 115:
# Timestamp (UTC): 2025-02-15 19:38:39.669291
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 116:
# Timestamp (UTC): 2025-02-15 19:38:39.669295
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 117:
# Timestamp (UTC): 2025-02-15 19:38:39.669300
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 118:
# Timestamp (UTC): 2025-02-15 19:38:39.669306
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 119:
# Timestamp (UTC): 2025-02-15 19:38:39.669310
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 120:
# Timestamp (UTC): 2025-02-15 19:38:39.669315
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 121:
# Timestamp (UTC): 2025-02-15 19:38:39.669319
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 122:
# Timestamp (UTC): 2025-02-15 19:38:39.669323
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 123:
# Timestamp (UTC): 2025-02-15 19:38:39.669328
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 124:
# Timestamp (UTC): 2025-02-15 19:38:39.669332
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 125:
# Timestamp (UTC): 2025-02-15 19:38:39.669336
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 126:
# Timestamp (UTC): 2025-02-15 19:38:39.669340
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 127:
# Timestamp (UTC): 2025-02-15 19:38:39.669344
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 128:
# Timestamp (UTC): 2025-02-15 19:38:39.669350
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 129:
# Timestamp (UTC): 2025-02-15 19:38:39.669358
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 130:
# Timestamp (UTC): 2025-02-15 19:38:39.669362
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 131:
# Timestamp (UTC): 2025-02-15 19:38:39.669367
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 132:
# Timestamp (UTC): 2025-02-15 19:38:39.669371
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 133:
# Timestamp (UTC): 2025-02-15 19:38:39.669375
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 134:
# Timestamp (UTC): 2025-02-15 19:38:39.669380
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 135:
# Timestamp (UTC): 2025-02-15 19:38:39.669385
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 136:
# Timestamp (UTC): 2025-02-15 19:38:39.669390
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 137:
# Timestamp (UTC): 2025-02-15 19:38:39.669394
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 138:
# Timestamp (UTC): 2025-02-15 19:38:39.669399
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 139:
# Timestamp (UTC): 2025-02-15 19:38:39.669405
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 140:
# Timestamp (UTC): 2025-02-15 19:38:39.669422
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 141:
# Timestamp (UTC): 2025-02-15 19:38:39.669462
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 142:
# Timestamp (UTC): 2025-02-15 19:38:39.669515
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 143:
# Timestamp (UTC): 2025-02-15 19:38:39.669577
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 144:
# Timestamp (UTC): 2025-02-15 19:38:39.669640
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 145:
# Timestamp (UTC): 2025-02-15 19:38:39.669705
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 146:
# Timestamp (UTC): 2025-02-15 19:38:39.669770
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 147:
# Timestamp (UTC): 2025-02-15 19:38:39.669832
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 148:
# Timestamp (UTC): 2025-02-15 19:38:39.669897
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 149:
# Timestamp (UTC): 2025-02-15 19:38:39.669960
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 150:
# Timestamp (UTC): 2025-02-15 19:38:39.670024
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 151:
# Timestamp (UTC): 2025-02-15 19:38:39.670089
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 152:
# Timestamp (UTC): 2025-02-15 19:38:39.670152
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 153:
# Timestamp (UTC): 2025-02-15 19:38:39.670216
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 154:
# Timestamp (UTC): 2025-02-15 19:38:39.670280
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 155:
# Timestamp (UTC): 2025-02-15 19:38:39.670345
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 156:
# Timestamp (UTC): 2025-02-15 19:38:39.670409
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 157:
# Timestamp (UTC): 2025-02-15 19:38:39.670473
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 158:
# Timestamp (UTC): 2025-02-15 19:38:39.670536
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 159:
# Timestamp (UTC): 2025-02-15 19:38:39.670600
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 160:
# Timestamp (UTC): 2025-02-15 19:38:39.670665
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 161:
# Timestamp (UTC): 2025-02-15 19:38:39.670728
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 162:
# Timestamp (UTC): 2025-02-15 19:38:39.670792
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 163:
# Timestamp (UTC): 2025-02-15 19:38:39.670856
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 164:
# Timestamp (UTC): 2025-02-15 19:38:39.670920
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 165:
# Timestamp (UTC): 2025-02-15 19:38:39.670984
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 166:
# Timestamp (UTC): 2025-02-15 19:38:39.671048
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 167:
# Timestamp (UTC): 2025-02-15 19:38:39.671113
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 168:
# Timestamp (UTC): 2025-02-15 19:38:39.671177
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 169:
# Timestamp (UTC): 2025-02-15 19:38:39.671240
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 170:
# Timestamp (UTC): 2025-02-15 19:38:39.671304
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 171:
# Timestamp (UTC): 2025-02-15 19:38:39.671369
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 172:
# Timestamp (UTC): 2025-02-15 19:38:39.671432
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 173:
# Timestamp (UTC): 2025-02-15 19:38:39.671497
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 174:
# Timestamp (UTC): 2025-02-15 19:38:39.671560
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 175:
# Timestamp (UTC): 2025-02-15 19:38:39.671624
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 176:
# Timestamp (UTC): 2025-02-15 19:38:39.671688
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 177:
# Timestamp (UTC): 2025-02-15 19:38:39.671755
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 178:
# Timestamp (UTC): 2025-02-15 19:38:39.671816
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 179:
# Timestamp (UTC): 2025-02-15 19:38:39.671880
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 180:
# Timestamp (UTC): 2025-02-15 19:38:39.671944
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 181:
# Timestamp (UTC): 2025-02-15 19:38:39.672009
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 182:
# Timestamp (UTC): 2025-02-15 19:38:39.672072
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 183:
# Timestamp (UTC): 2025-02-15 19:38:39.672136
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 184:
# Timestamp (UTC): 2025-02-15 19:38:39.672200
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 185:
# Timestamp (UTC): 2025-02-15 19:38:39.672264
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 186:
# Timestamp (UTC): 2025-02-15 19:38:39.672328
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 187:
# Timestamp (UTC): 2025-02-15 19:38:39.672394
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 188:
# Timestamp (UTC): 2025-02-15 19:38:39.672457
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 189:
# Timestamp (UTC): 2025-02-15 19:38:39.672520
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 190:
# Timestamp (UTC): 2025-02-15 19:38:39.672584
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 191:
# Timestamp (UTC): 2025-02-15 19:38:39.672648
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 192:
# Timestamp (UTC): 2025-02-15 19:38:39.672714
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 193:
# Timestamp (UTC): 2025-02-15 19:38:39.672777
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 194:
# Timestamp (UTC): 2025-02-15 19:38:39.672840
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 195:
# Timestamp (UTC): 2025-02-15 19:38:39.672905
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 196:
# Timestamp (UTC): 2025-02-15 19:38:39.672968
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 197:
# Timestamp (UTC): 2025-02-15 19:38:39.673032
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 198:
# Timestamp (UTC): 2025-02-15 19:38:39.673104
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 199:
# Timestamp (UTC): 2025-02-15 19:38:39.673162
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 200:
# Timestamp (UTC): 2025-02-15 19:38:39.673230
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 201:
# Timestamp (UTC): 2025-02-15 19:38:39.673290
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 202:
# Timestamp (UTC): 2025-02-15 19:38:39.673352
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 203:
# Timestamp (UTC): 2025-02-15 19:38:39.673417
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 204:
# Timestamp (UTC): 2025-02-15 19:38:39.673483
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 205:
# Timestamp (UTC): 2025-02-15 19:38:39.673544
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 206:
# Timestamp (UTC): 2025-02-15 19:38:39.673608
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 207:
# Timestamp (UTC): 2025-02-15 19:38:39.673672
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 208:
# Timestamp (UTC): 2025-02-15 19:38:39.673738
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 209:
# Timestamp (UTC): 2025-02-15 19:38:39.673800
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 210:
# Timestamp (UTC): 2025-02-15 19:38:39.673865
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 211:
# Timestamp (UTC): 2025-02-15 19:38:39.673928
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 212:
# Timestamp (UTC): 2025-02-15 19:38:39.673992
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 213:
# Timestamp (UTC): 2025-02-15 19:38:39.674056
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 214:
# Timestamp (UTC): 2025-02-15 19:38:39.674120
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 215:
# Timestamp (UTC): 2025-02-15 19:38:39.674185
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 216:
# Timestamp (UTC): 2025-02-15 19:38:39.674248
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 217:
# Timestamp (UTC): 2025-02-15 19:38:39.674312
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 218:
# Timestamp (UTC): 2025-02-15 19:38:39.674377
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 219:
# Timestamp (UTC): 2025-02-15 19:38:39.674440
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 220:
# Timestamp (UTC): 2025-02-15 19:38:39.674504
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 221:
# Timestamp (UTC): 2025-02-15 19:38:39.674569
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 222:
# Timestamp (UTC): 2025-02-15 19:38:39.674632
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 223:
# Timestamp (UTC): 2025-02-15 19:38:39.674697
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 224:
# Timestamp (UTC): 2025-02-15 19:38:39.674761
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 225:
# Timestamp (UTC): 2025-02-15 19:38:39.674824
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 226:
# Timestamp (UTC): 2025-02-15 19:38:39.674888
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 227:
# Timestamp (UTC): 2025-02-15 19:38:39.674953
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 228:
# Timestamp (UTC): 2025-02-15 19:38:39.675016
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 229:
# Timestamp (UTC): 2025-02-15 19:38:39.675081
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 230:
# Timestamp (UTC): 2025-02-15 19:38:39.675145
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 231:
# Timestamp (UTC): 2025-02-15 19:38:39.675209
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 232:
# Timestamp (UTC): 2025-02-15 19:38:39.675273
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 233:
# Timestamp (UTC): 2025-02-15 19:38:39.675337
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 234:
# Timestamp (UTC): 2025-02-15 19:38:39.675401
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 235:
# Timestamp (UTC): 2025-02-15 19:38:39.675466
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 236:
# Timestamp (UTC): 2025-02-15 19:38:39.675529
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 237:
# Timestamp (UTC): 2025-02-15 19:38:39.675592
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 238:
# Timestamp (UTC): 2025-02-15 19:38:39.675656
# Captured Length: 8330 bytes
# ...
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9923:
# Timestamp (UTC): 2025-02-15 19:38:40.295525
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9924:
# Timestamp (UTC): 2025-02-15 19:38:40.295589
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9925:
# Timestamp (UTC): 2025-02-15 19:38:40.295653
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9926:
# Timestamp (UTC): 2025-02-15 19:38:40.295717
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9927:
# Timestamp (UTC): 2025-02-15 19:38:40.295781
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9928:
# Timestamp (UTC): 2025-02-15 19:38:40.295845
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9929:
# Timestamp (UTC): 2025-02-15 19:38:40.295909
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9930:
# Timestamp (UTC): 2025-02-15 19:38:40.295973
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9931:
# Timestamp (UTC): 2025-02-15 19:38:40.296038
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9932:
# Timestamp (UTC): 2025-02-15 19:38:40.296101
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9933:
# Timestamp (UTC): 2025-02-15 19:38:40.296165
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9934:
# Timestamp (UTC): 2025-02-15 19:38:40.296229
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9935:
# Timestamp (UTC): 2025-02-15 19:38:40.296293
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9936:
# Timestamp (UTC): 2025-02-15 19:38:40.296357
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9937:
# Timestamp (UTC): 2025-02-15 19:38:40.296422
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9938:
# Timestamp (UTC): 2025-02-15 19:38:40.296488
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9939:
# Timestamp (UTC): 2025-02-15 19:38:40.296549
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9940:
# Timestamp (UTC): 2025-02-15 19:38:40.296614
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9941:
# Timestamp (UTC): 2025-02-15 19:38:40.296677
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9942:
# Timestamp (UTC): 2025-02-15 19:38:40.296741
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9943:
# Timestamp (UTC): 2025-02-15 19:38:40.296806
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9944:
# Timestamp (UTC): 2025-02-15 19:38:40.296869
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9945:
# Timestamp (UTC): 2025-02-15 19:38:40.296934
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9946:
# Timestamp (UTC): 2025-02-15 19:38:40.296997
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9947:
# Timestamp (UTC): 2025-02-15 19:38:40.297061
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9948:
# Timestamp (UTC): 2025-02-15 19:38:40.297125
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9949:
# Timestamp (UTC): 2025-02-15 19:38:40.297190
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9950:
# Timestamp (UTC): 2025-02-15 19:38:40.297253
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9951:
# Timestamp (UTC): 2025-02-15 19:38:40.297317
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9952:
# Timestamp (UTC): 2025-02-15 19:38:40.297385
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9953:
# Timestamp (UTC): 2025-02-15 19:38:40.297445
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9954:
# Timestamp (UTC): 2025-02-15 19:38:40.297510
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9955:
# Timestamp (UTC): 2025-02-15 19:38:40.297573
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9956:
# Timestamp (UTC): 2025-02-15 19:38:40.297637
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9957:
# Timestamp (UTC): 2025-02-15 19:38:40.297701
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9958:
# Timestamp (UTC): 2025-02-15 19:38:40.297765
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9959:
# Timestamp (UTC): 2025-02-15 19:38:40.297830
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9960:
# Timestamp (UTC): 2025-02-15 19:38:40.297893
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9961:
# Timestamp (UTC): 2025-02-15 19:38:40.297957
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9962:
# Timestamp (UTC): 2025-02-15 19:38:40.298021
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9963:
# Timestamp (UTC): 2025-02-15 19:38:40.298087
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9964:
# Timestamp (UTC): 2025-02-15 19:38:40.298150
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9965:
# Timestamp (UTC): 2025-02-15 19:38:40.298214
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9966:
# Timestamp (UTC): 2025-02-15 19:38:40.298278
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9967:
# Timestamp (UTC): 2025-02-15 19:38:40.298342
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9968:
# Timestamp (UTC): 2025-02-15 19:38:40.298405
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9969:
# Timestamp (UTC): 2025-02-15 19:38:40.298470
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9970:
# Timestamp (UTC): 2025-02-15 19:38:40.298535
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9971:
# Timestamp (UTC): 2025-02-15 19:38:40.298598
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9972:
# Timestamp (UTC): 2025-02-15 19:38:40.298661
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9973:
# Timestamp (UTC): 2025-02-15 19:38:40.298725
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9974:
# Timestamp (UTC): 2025-02-15 19:38:40.298789
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9975:
# Timestamp (UTC): 2025-02-15 19:38:40.298854
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9976:
# Timestamp (UTC): 2025-02-15 19:38:40.298917
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9977:
# Timestamp (UTC): 2025-02-15 19:38:40.298981
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9978:
# Timestamp (UTC): 2025-02-15 19:38:40.299045
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9979:
# Timestamp (UTC): 2025-02-15 19:38:40.299110
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9980:
# Timestamp (UTC): 2025-02-15 19:38:40.299173
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9981:
# Timestamp (UTC): 2025-02-15 19:38:40.299237
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9982:
# Timestamp (UTC): 2025-02-15 19:38:40.299301
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9983:
# Timestamp (UTC): 2025-02-15 19:38:40.299371
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9984:
# Timestamp (UTC): 2025-02-15 19:38:40.299430
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9985:
# Timestamp (UTC): 2025-02-15 19:38:40.299493
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9986:
# Timestamp (UTC): 2025-02-15 19:38:40.299558
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9987:
# Timestamp (UTC): 2025-02-15 19:38:40.299621
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9988:
# Timestamp (UTC): 2025-02-15 19:38:40.299685
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9989:
# Timestamp (UTC): 2025-02-15 19:38:40.299749
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9990:
# Timestamp (UTC): 2025-02-15 19:38:40.299813
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9991:
# Timestamp (UTC): 2025-02-15 19:38:40.299877
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9992:
# Timestamp (UTC): 2025-02-15 19:38:40.299941
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9993:
# Timestamp (UTC): 2025-02-15 19:38:40.300005
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9994:
# Timestamp (UTC): 2025-02-15 19:38:40.300070
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9995:
# Timestamp (UTC): 2025-02-15 19:38:40.300135
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9996:
# Timestamp (UTC): 2025-02-15 19:38:40.300198
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9997:
# Timestamp (UTC): 2025-02-15 19:38:40.300263
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9998:
# Timestamp (UTC): 2025-02-15 19:38:40.300326
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 9999:
# Timestamp (UTC): 2025-02-15 19:38:40.300391
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'
#
# Packet 10000:
# Timestamp (UTC): 2025-02-15 19:38:40.300456
# Captured Length: 8330 bytes
# Original Packet Length: 8330 bytes
# Payload (first 16 bytes): b'\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00'

# %%
header_number_bytes = 24 #bytes
payload_number_bytes = 8330 #bytes
timestamp_number_bytes = 16 #bytes
number_of_packets = 10000

total_bytes = header_number_bytes + (payload_number_bytes + timestamp_number_bytes) * number_of_packets
print("total bytes in the pcap: ", total_bytes)
# Out:
# total bytes in the pcap:  83460024

# %%
'''
Os arquivos .pcap foram formados com o comando
 > tcpdump ...
enquanto a Skarab funcionava com algum firmware.
'''

pcapfiles=sorted(glob.glob('*.pcap'))
print(len(pcapfiles),pcapfiles)
# Out:
# 1 ['zteste_2canais_fc110_2.pcap']

# %%
#escolher um arquivo da lista acima e abir-lo (ou seja, colocar no buffer) como um arquivo binário para leitura (opção 'rb')
num=1
esse=pcapfiles[0]
print(esse)
with open(esse,'rb') as f:
    mybuff=f.read()
# Out:
# zteste_2canais_fc110_2.pcap

# %%
#mostrar tamanho em bytes (8 bits)
print("size of pcap file (in bytes): ",len(mybuff))
#mostrar em formato binário (scary!) 
print(mybuff[:60])
#mostrar em formato hexdecimal (less scary!)
print(mybuff[:60].hex())
# Out:
# size of pcap file (in bytes):  83460024
# b'\xd4\xc3\xb2\xa1\x02\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x01\x00\x00\x00?\xed\xb0g\x1a3\n\x00\x8a \x00\x00\x8a \x00\x00\x1c\xfd\x08}X\x99\x06P\x02\x0f\x03\x01\x08\x00E\x00 |\x00\x00'
# d4c3b2a102000400000000000000000000000400010000003fedb0671a330a008a2000008a2000001cfd087d58990650020f030108004500207c0000

# %%
"""
Transformar em um np.array formado de int8 o array acima para manter a quantidade de números.
Isso vai ajudar a manipular o array com os métodos do numpy
Removemos os 24 primeiros elementos, pois é uma espécie de header geral. 
O procedimento será ir descobrindo o que é header geral (comparando com o output do wireshark),
e depois ver o que é header e dados em cada header
"""

dt = np.dtype('int8')
coisa_int8=np.frombuffer(mybuff,dt)
newcoisa_int8=coisa_int8[24:]
print(newcoisa_int8.shape)
newcoisa_int8[:100].data.hex()
# Out:
# (83460000,)
# '3fedb0671a330a008a2000008a2000001cfd087d58990650020f030108004500207c00004000ff11513b0a2a000c000000002710000020680000530402060000000b800100000005addf8002000000080000800300000000000080040000000020009011'

# %%
# fazer um reshape com 8346 e o que sobre é o número de frames.
# Controlamos o número de frames com o flag -c no tcpdump
nn_re=newcoisa_int8.reshape(-1,8346)
print(nn_re.shape)
print(nn_re)
# notar que as colunas iniciais são iguais, implicando algum tipo de header (iguais) de cada frame
# Out:
# (10000, 8346)
# [[ 63 -19 -80 ...  -3   0   0]
#  [ 63 -19 -80 ...   1   0   2]
#  [ 63 -19 -80 ...   0  -1  -3]
#  ...
#  [ 64 -19 -80 ...   3   0   1]
#  [ 64 -19 -80 ...   3  -1  -2]
#  [ 64 -19 -80 ...  -2  -1  -1]]

# %%
# retira um header antes dos dados do UDP...o pacote UDP tem 8330 bytes (ou int8) de acordo com o wireshark 
# Daí tem uma parte para ser removida até 2888 e por fim dados mesmo são 8192. 
# Portanto será preciso remover ainda 8330-8192=138 elementos no início de cada frame
new_re=nn_re[:,16:] 
print(new_re.shape)
print(new_re[:10,:10])
print(new_re.flatten()[:148].data.hex())
# Out:
# (10000, 8330)
# [[  28   -3    8  125   88 -103    6   80    2   15]
#  [  28   -3    8  125   88 -103    6   80    2   15]
#  [  28   -3    8  125   88 -103    6   80    2   15]
#  [  28   -3    8  125   88 -103    6   80    2   15]
#  [  28   -3    8  125   88 -103    6   80    2   15]
#  [  28   -3    8  125   88 -103    6   80    2   15]
#  [  28   -3    8  125   88 -103    6   80    2   15]
#  [  28   -3    8  125   88 -103    6   80    2   15]
#  [  28   -3    8  125   88 -103    6   80    2   15]
#  [  28   -3    8  125   88 -103    6   80    2   15]]
# 

# %%
final_re=new_re[:,138:]
print(final_re.shape)
print(final_re[:10,:10])
print(final_re.flatten()[:10].data.hex())
# Out:
# (10000, 8192)
# [[  -1   91    0   67   -1   -4    0    0   -1  -52]
#  [  -1  -87    0   20    0    1    0    4   -1  -71]
#  [   0   17   -1  -41   -1   -7    0    2    0   97]
#  [   0   83   -1  -15    0    2    0    3    0   66]
#  [  -1 -108   -1  -63   -1   -2    0    0    0   70]
#  [   0   20    0   82   -1   -4    0    3   -1  -17]
#  [   0   15    0   56    0    1   -1   -1    0   46]
#  [   0   24   -1 -108    0    0    0    0    0   74]
#  [  -1  -85   -1  -83   -1   -3   -1   -3   -1  -70]
#  [   0   16   -1 -117    0    3    0    3    0   51]]
# ff5b0043fffc0000ffcc

# %%
te1=final_re.reshape(-1)  # pode ser usado o método .flatten().
print(te1.shape)
print(te1[:10])

# As linhas abaixo é para fazer um check de comparação se o reshape(-1) ou .flatten funciona direito
#te3=te1.reshape(-1,8192)  #just to test and check with final_re
#print(te3.shape)
#te3[:10,:10]
# Out:
# (81920000,)
# [ -1  91   0  67  -1  -4   0   0  -1 -52]

# %%
# Voltar para bytes
te1_bytes=te1.tobytes()

# caso queira ver em hex.
#te1_hex=te1.data.hex()
#print(te1_hex[:50])

# %%
# os dados estão codificados em int16. Agora é para valer:

dt = np.dtype('int16')
coisa=np.frombuffer(te1_bytes,dt)
print(coisa.shape)
# Out:
# (40960000,)

# %%
#Plotando uma amostra. Não vai fazer sentido. Tem que separar ainda os dados.
plt.plot(coisa[:512])

# %%
# Separando. Há duas entradas pela skarab sendo lendo, a entrada 0, in0, e a entrada 1, in1; 
# Em cada entrada, tem-se os dados em I/Q, ou seja, parte real e parte imaginária;
# A cada 4 elementos, tem-se na sequência in0_im, in0_re, in1_im, in1_re

in0_im=coisa[::4]
in0_re=coisa[1::4]
in1_im=coisa[2::4]
in1_re=coisa[3::4]

# para o futuro, já fazemos a combinação dos sinais em um único número complexo
in0_c = in0_re+1j*in0_im
in1_c= in1_re+1j*in1_im

# %%
#plotando uma pequena amostra de cada componente. Difícil de entender e visualizar
kk=512
fig,ax=plt.subplots(2,2)
ax[0,0].plot(in0_im[:kk])
ax[0,1].plot(in0_re[:kk])
ax[1,0].plot(in1_im[:kk])
ax[1,1].plot(in1_re[:kk])

# %%
#Fazendo os waterfall (espectrograma) para analisar os dados melhor

# Definir o sampling rate efetivo, ou seja, sampling rate real que foi selecionado dividido pela decimação selecionada, 
# por exemplo, 2048 MHz/128=16 MHz, que vai ser a bandwidth
# Definir o número de canais nfft
# Definir a frequência central selecionada
fs1=16*1e6
nfft=512
fc=110e6

# %%
# Organizando os gráficos
fig,ax=plt.subplots(2,2,figsize=(15,10))

myindex=50

spec,freqs,times,im=ax[0,0].specgram(in0_c,Fs=fs1,NFFT=nfft,Fc=fc,sides='twosided')  #waterfall 
ax[0,1].plot(freqs/1e6,spec[:,myindex], label=f'antena \n instante {times[myindex]:.3} s')  # um espectro em um dado instante
ax[0,1].legend(loc='upper left',fontsize=8)

ax[0,0].set_ylabel('frequência (Hz)')
ax[0,0].set_xlabel('tempo (s)')
cbr0=plt.colorbar(im)
cbr0.set_label('Power Spectrum Density (V^2/Hz)')

ax[0,1].set_xlabel('frequência(MHz)')



lspec,lfreqs,ltimes,lim=ax[1,0].specgram(in1_c,Fs=fs1,NFFT=nfft,Fc=fc,sides='twosided')
ax[1,1].plot(lfreqs/1e6,lspec[:,myindex], label=f'tom \n instante {ltimes[myindex]:.3} s')  # um espectro em um dado instante
ax[1,1].legend(loc='upper left',fontsize=8)

ax[1,0].set_ylabel('frequência (Hz)')
ax[1,0].set_xlabel('tempo (s)')
cbr1=plt.colorbar(lim)
cbr1.set_label('Power Spectrum Density (V^2/Hz)')

ax[1,1].set_xlabel('frequência(MHz)')

fig.suptitle(f'Canal 0: Antena ; Canal 1: Gerador de Sinal \n fs = {fs1/1e6} MHz; fc = {fc/1e6} MHz; NFFT: {nfft};  ',fontsize=16);

#fig.savefig('Skarab_2canais_2025Feb15.png')
